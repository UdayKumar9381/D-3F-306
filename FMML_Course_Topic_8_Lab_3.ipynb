# %% [markdown]
# <a href="https://colab.research.google.com/github/UdayKumar9381/D-3F-306/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-04 18:49:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   181MB/s    in 0.4s
#
# 2024-04-04 18:49:20 (181 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 4107 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 10  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11203  1501.03326v2  A key quantity of interest in Bayesian inferen...  stat
# 6290   1610.09420v1  Low-rank matrix factorizations arise in a wide...  stat
# 26278  1609.06434v1  Partial least squares regression (PLSR) has be...    cs
# 21016  1706.06366v2  The highly influential framework of conceptual...    cs
# 4875   1609.05473v6  As a new way of training generative models, Ge...    cs
# ...             ...                                                ...   ...
# 22982  1712.03353v1  Performing inference over simulators is genera...  stat
# 7564   1802.03644v1  We consider recommendation in the context of o...  stat
# 15711  1602.07572v2  Embeddings are generic representations that ar...    cs
# 30968  1801.10447v1  Recently there has been a lot of work on pruni...    cs
# 35774   1204.4307v1  Based on Cumulative Number of Confirmed Human ...    cs
#
#                                                    title  year  \
# 11203  Unbiased Bayes for Big Data: Paths of Partial ...  2015
# 6290   Dynamic matrix recovery from incomplete observ...  2016
# 26278  Partial Least Squares Regression on Riemannian...  2016
# 21016      A Thorough Formalization of Conceptual Spaces  2017
# 4875   SeqGAN: Sequence Generative Adversarial Nets w...  2016
# ...                                                  ...   ...
# 22982  Variational Inference over Non-differentiable ...  2017
# 7564   Learning to Recommend via Inverse Optimal Matc...  2018
# 15711  Ultradense Word Embeddings by Orthogonal Trans...  2016
# 30968  Recovering from Random Pruning: On the Plastic...  2018
# 35774  Avian Influenza (H5N1) Warning System using De...  2012
#
#                                                 keywords
# 11203  [inference, expectations, functions, posterior...
# 6290   [factorizations, applications, including, reco...
# 26278  [regression, technique, relationship, algorith...
# 21016  [influential, framework, conceptual, geometric...
# 4875   [generative, generative, adversarial, discrimi...
# ...                                                  ...
# 22982  [performing, inference, simulators, generally,...
# 7564   [recommendation, framework, particularly, indi...
# 15711  [embeddings, representations, introduce, densi...
# 30968  [convolutional, intention, computations, crite...
# 35774  [cumulative, confirmed, influenza, organizatio...
#
# [4800 rows x 6 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['keywords'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# train_df['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# train_df.groupby('tag').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['year']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'year'}, axis=1)
#               .sort_values('year', ascending=True))
#   xs = counted['year']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = train_df.sort_values('year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('tag')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='tag', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# train_df['year'].plot(kind='line', figsize=(8, 4), title='year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(train_df['tag'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(train_df, x='year', y='tag', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['keywords'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('tag').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='index', y='year', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['year']
#   ys = series['index']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('tag')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='tag', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('index')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['year']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'year'}, axis=1)
#               .sort_values('year', ascending=True))
#   xs = counted['year']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('tag')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='tag', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['year'].plot(kind='line', figsize=(8, 4), title='year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_8['tag'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_8, x='index', y='tag', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['tag'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='year', y='tag', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df['keywords']
# Out:
# 11203    [inference, expectations, functions, posterior...
# 6290     [factorizations, applications, including, reco...
# 26278    [regression, technique, relationship, algorith...
# 21016    [influential, framework, conceptual, geometric...
# 4875     [generative, generative, adversarial, discrimi...
#                                ...
# 2898     [convolutional, demonstrated, excellent, perfo...
# 24746    [challenging, unsupervised, automatically, dim...
# 33836    [implementation, neuromorphic, complementary, ...
# 23027    [simultaneously, prediction, generalization, p...
# 22000    [derivation, implementation, variational, infe...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8788 words.
# Out of those 4575 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c920ae31-ea44-453f-9c34-a9efc3cfe596" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c920ae31-ea44-453f-9c34-a9efc3cfe596")) {                    Plotly.newPlot(                        "c920ae31-ea44-453f-9c34-a9efc3cfe596",                        [{"x":["approximate","construction","fundamental","distribution","expectations","tolerance","parameters","posterior","averaging","posteriors","challenged","straightforward","naturally","benchmark","computational","feasibility","consistently","computationally","iteration","processed","functions","methodology","demonstrate","generality","unnecessarily","simulation","inference","statistical","complexity","algorithms","estimation","construct","constraints","establish","completion","potential","constraint","counterparts","experimental","illustrate","factorizations","empirical","introducing","smoothing","synthetic","justification","observations","performance","theoretical","observation","dynamically","information","applications","incorporating","including","possibility","separation","improvements","incomplete","framework","exploiting","significant","recovering","recommendation","application","algorithm","riemannian","euclidean","experiments","recognition","solutions","manifolds","relationship","classification","classifications","suboptimal","demonstrated","implementations","regression","technique","optimization","calculate","instances","represented","dimensional","operations","formalization","geometric","correlations","influential","parametric","represent","knowledge","conceptual","requirement","efficient","different","representing","projection","processes","convexity","definition","reasoning","differentiation","considerable","limitations","intermediate","adversarial","discriminator","stochastic","partially","generation","reinforcement","generative","difficult","sequences","generating","discriminative","extensive","generator","generated","performing","baselines","attributes","comparisons","localization","informative","simultaneously","significantly","convolutional","attribute","processing","qualitative","meaningful","discovers","supervised","considering","available","correspond","introduce","formalisms","equivalence","simulated","biological","procedures","incorporate","relations","incorporation","specifically","ancestral","inferences","conjecture","multiarmed","expression","converting","efficiency","unsupervised","symmetric","representations","resolution","distributions","relatively","scattering","performed","advantages","outperform","invariant","translation","transformation","presented","exponential","numerical","conditional","advantage","graphical","semiparametric","generalized","unnecessary","hypothesis","parameter","unspecified","particular","convenient","inferential","dimensions","parametrizations","simulations","combination","researchers","therefore","synergies","heuristic","evaluated","guarantee","combinatorial","elementary","promising","simulates","necessary","combinations"],"y":[108,73,84,206,10,2,240,36,18,3,6,16,75,203,281,17,41,88,42,26,201,65,538,14,0,69,200,164,226,636,212,82,140,49,29,149,89,20,379,58,3,158,41,19,135,9,74,915,152,63,36,683,415,53,233,49,18,113,39,550,67,224,22,32,251,812,12,34,626,383,125,19,72,516,3,14,101,37,114,257,351,19,108,105,188,69,4,55,42,8,44,104,366,24,30,384,733,55,54,94,6,35,136,6,46,58,39,100,16,117,52,144,124,114,145,119,122,103,178,34,155,89,69,65,28,80,31,121,255,384,39,289,66,45,8,179,82,308,25,331,15,32,54,50,48,48,81,7,193,1,12,6,1,43,10,151,154,18,256,115,121,56,9,130,78,94,65,128,57,190,39,76,85,107,45,1,69,9,45,113,0,257,17,1,46,1,38,138,84,151,2,65,148,33,36,15,109,2,75,35],"type":"bar"},{"x":["approximate","construction","fu ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4575,), (4575, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8166666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Action</span> <span style=''>Models</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>Qualitative</span> <span style=''>Approach</span> <br/><br/><span style=''>In</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>epistemic</span> <span style=''>logic</span> <span style=''>actions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>using</span> <span style=''>action</span> <span style=''>models</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>studying</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>learnability</span> <span style=''>of</span> <span style=''>action</span> <span style=''>models</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3242009132420091);'>observations</span> <span style=''>We</span> <span style=''>present</span> <span style=''>first</span> <span style=''>results</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concerning</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propositional</span> <span style=''>action</span> <span style=''>models</span> <span style=''>First</span> <span style=''>we</span> <span style=''>check</span> <span style=''>two</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>learnability</span> <span style=''>criteria</span> <span style=''>finite</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>identifiability</span> <span style=''>(conclusively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inferring</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style=''>action</span> <span style=''>model</span> <span style=''>in</span> <span style=''>finite</span> <span style=''>time)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>identifiability</span> <span style=''>in</span> <span style=''>the</span> <span style=''>limit</span> <span style=''>(inconclusive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>to</span> <span style=''>the</span> <span style=''>right</span> <span style=''>action</span> <span style=''>model)</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style=''>actions</span> <span style=''>are</span> <span style=''>finitely</span> <span style='background-color:rgba(255, 0, 0, 0.5999999999999999);'>identifiable</span> <span style=''>while</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style=''>actions</span> <span style=''>require</span> <span style=''>more</span> <span style=''>learning</span> <span style=''>power</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.5999999999999999);'>identifiable</span> <span style=''>in</span> <span style=''>the</span> <span style=''>limit</span> <span style=''>We</span> <span style=''>then</span> <span style=''>move</span> <span style=''>on</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>which</span> <span style=''>proceeds</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restriction</span> <span style=''>of</span> <span style=''>a</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalised</span> <span style=''>von</span> <span style=''>Mises</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <br/><br/><span style=''>Circular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multitude</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>contexts</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>robotics</span> <span style=''>to</span> <span style=''>the</span> <span style=''>social</span> <span style=''>sciences</span> <span style=''>but</span> <span style=''>they</span> <span style=''>have</span> <span style=''>been</span> <span style=''>largely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overlooked</span> <span style=''>by</span> <span style=''>the</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redresses</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalance</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style=''>some</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>tools</span> <span style=''>to</span> <span style=''>the</span> <span style=''>circular</span> <span style=''>domain</span> <span style=''>First</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style=''>circular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>called</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalised</span> <span style=''>von</span> <span style=''>Mises</span> <span style=''>(mGvM)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricting</span> <span style=''>and</span> <span style=''>renormalising</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>to</span> <span style=''>the</span> <span style=''>unit</span> <span style=''>hyper</span> <span style=''>torus</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Previously</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>circular</span> <span style='background-color:rgba(0, 255, 0, 0.3 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Tractable</span> <span style=''>Schatten</span> <span style=''>Quasi</span> <span style=''>Norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <br/><br/><span style=''>The</span> <span style=''>Schatten</span> <span style=''>p</span> <span style=''>quasi</span> <span style=''>norm</span> <span style=''>(0p1)</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>used</span> <span style=''>to</span> <span style=''>replace</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style=''>rank</span> <span style=''>function</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style=''>However</span> <span style=''>existing</span> <span style=''>Schatten</span> <span style=''>p</span> <span style=''>quasi</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>involve</span> <span style=''>singular</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>(SVD)</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.8095238095238095);'>eigenvalue</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>(EVD)</span> <span style=''>in</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>may</span> <span style=''>become</span> <span style=''>very</span> <span style=''>slow</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impractical</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>problems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style=''>define</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>Schatten</span> <span style=''>quasi</span> <span style=''>norms</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>Frobeniusnuclear</span> <span style=''>hybrid</span> <span style=''>and</span> <span style=''>bi</span> <span style=''>nuclear</span> <span style=''>quasi</span> <span style=''>norms</span> <span style=''>and</span> <span style=''>then</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>they</span> <span style=''>are</span> <span style=''>in</span> <span style=''>essence</span> <span style=''>the</span> <span style=''>Schatten</span> <span style=''>23</span> <span style=''>and</span> <span style=''>12</span> <span style=''>quasi</span> <span style=''>norms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>respectively</span> <span style=''>which</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>the</span> <span style=''>design</span> <span style=''>of</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>only</span> <span style=''>need</span> <span style=''>to</span> <span style=''>update</span> <span style=''>two</span> <span style=''>much</span> <span style=''>smaller</span> <span style=''>factor</span> <span style=''>mat ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>and</span> <span style=''>Tracking</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Arbitrary</span> <span style=''>Objects</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>Process</span> <span style=''>Mixtures</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>and</span> <span style=''>tracking</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>videos</span> <span style=''>It</span> <span style=''>is</span> <span style=''>intended</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>localization</span> <span style=''>methods</span> <span style=''>tailored</span> <span style=''>to</span> <span style=''>specific</span> <span style=''>object</span> <span style=''>types</span> <span style=''>and</span> <span style=''>serve</span> <span style=''>as</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>videos</span> <span style=''>with</span> <span style=''>varied</span> <span style=''>objects</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>backgrounds</span> <span style=''>and</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualities</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>process</span> <span style=''>mixture</span> <span style=''>(DDPM)</span> <span style=''>known</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style=''>Polya</span> <span style=''>Urn</span> <span style=''>(GPUDDPM)</span> <span style=''>to</span> <span style=''>model</span> <span style=''>image</span> <span style=''>pixel</span> <span style=''>data</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>from</span> <span style=''>the</span> <span style=''>regions</span> <span style=''>in</span> <span style=''>a</span> <span style=''>video</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>objects</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>a</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07315340909090909)
# 	segmentation (0.06427556818181818)
# 	knowledge (0.1299715909090909)
# 	information (0.24254261363636365)
# 	architecture (0.08735795454545454)
# 	different (0.26029829545454547)
# 	representation (0.1395596590909091)
# 	detection (0.13316761363636365)
# 	convolutional (0.13636363636363635)
# 	recognition (0.13600852272727273)
#
# Some Statistics words are:
# 	stochastic (0.12953629032258066)
# 	theoretical (0.14566532258064516)
# 	statistical (0.15171370967741934)
# 	estimation (0.17036290322580644)
# 	variables (0.13911290322580644)
# 	algorithm (0.39213709677419356)
# 	distribution (0.18346774193548387)
# 	dimensional (0.1819556451612903)
# 	inference (0.19153225806451613)
# 	regression (0.1844758064516129)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="59efc84f-456f-4452-b6c0-9952ad2b1dea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59efc84f-456f-4452-b6c0-9952ad2b1dea")) {                    Plotly.newPlot(                        "59efc84f-456f-4452-b6c0-9952ad2b1dea",                        [{"x":["approximate","construction","fundamental","distribution","expectations","tolerance","parameters","posterior","averaging","posteriors","challenged","straightforward","naturally","benchmark","computational","feasibility","consistently","computationally","iteration","processed","functions","methodology","demonstrate","generality","unnecessarily","simulation","inference","statistical","complexity","algorithms","estimation","construct","constraints","establish","completion","potential","constraint","counterparts","experimental","illustrate","factorizations","empirical","introducing","smoothing","synthetic","justification","observations","performance","theoretical","observation","dynamically","information","applications","incorporating","including","possibility","separation","improvements","incomplete","framework","exploiting","significant","recovering","recommendation","application","algorithm","riemannian","euclidean","experiments","recognition","solutions","manifolds","relationship","classification","classifications","suboptimal","demonstrated","implementations","regression","technique","optimization","calculate","instances","represented","dimensional","operations","formalization","geometric","correlations","influential","parametric","represent","knowledge","conceptual","requirement","efficient","different","representing","projection","processes","convexity","definition","reasoning","differentiation","considerable","limitations","intermediate","adversarial","discriminator","stochastic","partially","generation","reinforcement","generative","difficult","sequences","generating","discriminative","extensive","generator","generated","performing","baselines","attributes","comparisons","localization","informative","simultaneously","significantly","convolutional","attribute","processing","qualitative","meaningful","discovers","supervised","considering","available","correspond","introduce","formalisms","equivalence","simulated","biological","procedures","incorporate","relations","incorporation","specifically","ancestral","inferences","conjecture","multiarmed","expression","converting","efficiency","unsupervised","symmetric","representations","resolution","distributions","relatively","scattering","performed","advantages","outperform","invariant","translation","transformation","presented","exponential","numerical","conditional","advantage","graphical","semiparametric","generalized","unnecessary","hypothesis","parameter","unspecified","particular","convenient","inferential","dimensions","parametrizations","simulations","combination","researchers","therefore","synergies","heuristic","evaluated","guarantee","combinatorial","elementary","promising","simulates","necessary","combinations","strategies","sufficient","transport","participate","architectures","inception","techniques","bilateral","comparison","structured","architecture","inserting","respecting","prediction","superpixel","propagates","segmentation","backpropagation","superpixels","competitive","addresses","filtering","increasingly","experiment","attention","expensive","evaluations","practical","outperforms","iterations","continuous","approximations","characterise","properties","optimisation","validation","temperature","maximization","clustering","effectiveness","anomalies","asymmetric","expectation","regarding","likelihood","robustness","maximizing","dedicated","heterogeneity","monotonically","usefulness","statistics","unsuita ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unnecessarily
# 	unspecified
# 	frequentist
# 	imbalances
# 	tradition
# 	prescribing
# 	quadratically
# 	heteroscedasticity
# 	statisticians
# 	confounders
# 	conformalized
# 	admitting
# 	unavailability
# 	conjugacy
# 	heteroscedastic
# 	positivity
# 	amortization
# 	actigraphy
# 	consonants
# 	scrambled
# Some words which never appear in Statistics papers:
# 	formalisms
# 	synergies
# 	bilateral
# 	inserting
# 	superpixel
# 	propagates
# 	deformation
# 	articulated
# 	recurring
# 	synchronizing
# 	histology
# 	vesicular
# 	epithelial
# 	illumination
# 	discoverable
# 	angiography
# 	morphologically
# 	vectorization
# 	morphemes
# 	lambertian

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.054834275240568e-05

# %%
words_to_index = defaultdict(lambda: -2)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7191666666666666
